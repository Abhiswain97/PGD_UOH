# %%
import math


def f(x):
    if x != 0:
        return math.sin(x) / x
    else:
        return 1.0

# %%
def slope_f(x, delta=0.001):
    return (f(x + delta) - f(x)) / delta

# %%
# Find maxima in range -2, 2
import random

# init
x_l = -2
x_u = +2
x = (x_u + x_l) / 2

# iterate
while True:  # Alwasys TRUE

    if math.isnan(
        slope_f(x, delta=0.001)
    ):  # Fix NAN case with random pertubation of x.
        x = x + random.random() / 100

    if (
        abs(slope_f(x, delta=0.001)) < 0.0001
    ):  # BREAK condition NOTE the less-than. [COMMON MISTAKE: >]
        break

    x = (x_u + x_l) / 2
    # middle point
    if slope_f(x, delta=0.001) > 0:  # adjust x_l
        x_l = x
    else:  # adjust x_u
        x_u = x

    print(slope_f(x, delta=0.001), x_l, x_u)

print("x:" + str(x) + "\t slope_f(x, delta=0.001): " + str(slope_f(x, delta=0.001)))
# Out:
# -0.0001666666583632903 -2 0.0
# 0.3010490826154122 -1.0 0.0
# 0.16238266299084536 -0.5 0.0
# 0.08265009969277148 -0.25 0.0
# 0.041435708526327275 -0.125 0.0
# 0.020658722974076227 -0.0625 0.0
# 0.01024903057489368 -0.03125 0.0
# 0.005041551205509087 -0.015625 0.0
# 0.0024374869050936 -0.0078125 0.0
# 0.0011354153208742446 -0.00390625 0.0
# 0.0004843748855343222 -0.001953125 0.0
# 0.0001588541590491488 -0.0009765625 0.0
# -3.906249990137667e-06 -0.0009765625 -0.00048828125
# x:-0.00048828125	 slope_f(x, delta=0.001): -3.906249990137667e-06
